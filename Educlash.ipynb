# %% [markdown]
# <a href="https://colab.research.google.com/github/akhythmetic/EDUCLASH/blob/main/Educlash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ÉDUCATION
# ## *Bellum Lycei Privati et Publici*

# %%
# !pip install requests
import requests

# %% [markdown]
# recuperation data

# %%
url = "https://public.opendatasoft.com/api/explore/v2.1/catalog/datasets"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print("Erreur lors de la récupération des données")
# Out:
# {'total_count': 572, 'results': [{'visibility': 'domain', 'dataset_id': 'analytical-house-prices-indicators', 'dataset_uid': 'da_5xdp0y', 'has_records': True, 'features': ['analyze', 'geo', 'timeserie'], 'attachments': [], 'alternative_exports': [], 'data_visible': True, 'fields': [{'name': 'time_serie', 'description': 'Date of the indicator value', 'annotations': {'facetsort': '-count', 'timeserie_precision': 'month', 'facet': True}, 'label': 'Date', 'type': 'date'}, {'name': 'country', 'description': 'Country name', 'annotations': {'facet': True, 'disjunctive': True, 'sortable': True}, 'label': 'Country', 'type': 'text'}, {'name': 'nominal_house_price_indices_s_a', 'description': 'Nominal house prices deflated using the private consumption deflator from the national account statistics\nIndex : 2015 = 100', 'annotations': {'facetsort': '-count'}, 'label': 'Nominal house price indices, s.a.', 'type': 'double'}, {'name': 'price_to_income_ratio', 'description': 'The price-to-income rat
# ...

# %%
url = "https://public.opendatasoft.com/api/explore/v2.1/catalog/datasets?limit=5"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print("Erreur :", response.status_code)
# Out:
# {'total_count': 572, 'results': [{'visibility': 'domain', 'dataset_id': 'analytical-house-prices-indicators', 'dataset_uid': 'da_5xdp0y', 'has_records': True, 'features': ['analyze', 'geo', 'timeserie'], 'attachments': [], 'alternative_exports': [], 'data_visible': True, 'fields': [{'name': 'time_serie', 'description': 'Date of the indicator value', 'annotations': {'facetsort': '-count', 'timeserie_precision': 'month', 'facet': True}, 'label': 'Date', 'type': 'date'}, {'name': 'country', 'description': 'Country name', 'annotations': {'facet': True, 'disjunctive': True, 'sortable': True}, 'label': 'Country', 'type': 'text'}, {'name': 'nominal_house_price_indices_s_a', 'description': 'Nominal house prices deflated using the private consumption deflator from the national account statistics\nIndex : 2015 = 100', 'annotations': {'facetsort': '-count'}, 'label': 'Nominal house price indices, s.a.', 'type': 'double'}, {'name': 'price_to_income_ratio', 'description': 'The price-to-income rat
# ...
